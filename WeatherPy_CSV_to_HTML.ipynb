# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
# Make a reference to the books.csv file path
csv_path = "../Desktop/HTML-CSS-Homework/WeatherPy.csv"

# %%
# Import the books.csv file as a DataFrame
weather_data_df = pd.read_csv(csv_path, encoding="utf-8")
weather_data_df.head(550)
# Out:
#                  City Name  Cloudiness Country        Date  Humidity    Lat  \
# 0            Mokhsogollokh          53      RU  1562971171        52  61.40
# 1                    Adrar           0      DZ  1562971172         5  27.87
# 2               Nikolskoye           0      RU  1562971174        87  59.70
# 3      Rancho Palos Verdes          20      US  1562970943        73  33.75
# 4                  Mityana          20      UG  1562971176        94   0.40
# 5                  Rikitea           4      PF  1562971177        80 -23.12
# 6                  Mataura          99      NZ  1562971179        76 -46.19
# 7                Carnarvon           0      ZA  1562971180        25 -30.97
# 8                   Zaranj           0      AF  1562971181        24  30.95
# 9                   Dikson           1      RU  1562971183        92  73.51
# 10                  Kodiak           1      US  1562971184        11  39.95
# 11    Vila Franca do Campo          20      PT  1562971185        77  37.72
# 12                 Ushuaia          75      AR  1562971187        80 -54.81
# 13               Upernavik           8      GL  1562971126        74  72.79
# 14          Saint-Augustin          75      CA  1562971189        69  45.63
# 15              Whitehorse          90      CA  1562971191        49  60.72
# 16                   Vaini         100      IN  1562971192        92  15.34
# 17               Busselton          99      AU  1562971193        84 -33.64
# 18                  Lisala          99      CD  1562971194        90   2.15
# 19                 Fortuna          20      US  1562971098        68  40.60
# 20            Punta Arenas          90      CL  1562971197       100 -53.16
# 21                  Turbat          42      PK  1562971198        81  26.00
# 22                Tasiilaq           0      GL  1562971200        81  65.61
# 23       Sao Joao da Barra           0      BR  1562971201        82 -21.64
# 24             Port Alfred          81      ZA  1562971202        86 -33.59
# 25                   Pevek          74      RU  1562971207        91  69.70
# 26                  Albany          75      US  1562970927        61  42.65
# 27                  Eureka           1      US  1562971209        68  40.80
# 28                Wangqing          43      CN  1562971211        73  43.31
# 29                Cherskiy          38      RU  1562971212        55  68.75
# ..                     ...         ...     ...         ...       ...    ...
# 518                Madimba          75      CM  1562971913       100   4.42
# 519                Kletnya           0      RU  1562971914        94  53.39
# 520             Khairagarh         100      IN  1562971916        91  21.42
# 521                 Burnie          54      AU  1562971712        73 -41.05
# 522                Posadas           0      PY  1562971646        53 -27.37
# 523                Jackson           1      US  1562971808        66  32.30
# 524              Dibrugarh         100      IN  1562971923        99  27.48
# 525                 Sindou          82      BF  1562971924        93  10.66
# 526                  Khash           0      IR  1562971925        39  28.22
# 527                  Tabou          96      CI  1562971927        92   4.42
# 528                  Keene           1      US  1562971813        54  42.93
# 529                   Axim          81      GH  1562971929        91   4.87
# 530               Ovsyanka          47      RU  1562971930        52  53.58
# 531              Boa Vista          54      BR  1562971932        76   2.82
# 532                  Kutum          98      SD  1562971933        44  14.20
# 533              Ewa Beach          40      US  1562971934        43  21.32
# 534                 Moerai           0      PF  1562971936        82 -22.43
# 535                Akhmeta          40      GE  1562971937        68  42.03
# 536                  Bajil          88      ES  1562971938        44  38.23
# 537  Reguengos de Monsaraz           0      PT  1562971940        73  38.42
# 538                 Matata          82      NZ  1562971941        84 -37.89
# 539                  Coria          68      ES  1562971942        63  39.98
# 540              Kavaratti          40      IN  1562971944        79  10.57
# 541             Shenjiamen         100      CN  1562971945        95  29.96
# 542                Jeremie          40      HT  1562971946        77  18.65
# 543          Moose Factory          90      CA  1562971948        87  51.26
# 544              Mahajanga          40      MG  1562971949        57 -15.72
# 545                  Pisco          40      PE  1562971951        30 -13.71
# 546               Tamiahua           2      MX  1562971952        76  21.28
# 547                 Gorele          75      TR  1562971953        88  41.03
#
#         Lng  Max Temp  Wind Speed
# 0    128.95     79.59        2.82
# 1     -0.29    100.40       11.41
# 2     30.79     52.00        4.47
# 3   -118.37     93.00       18.34
# 4     32.05     68.00        4.70
# 5   -134.97     74.01       16.11
# 6    168.86     54.00        7.00
# 7     22.13     54.39        9.57
# 8     61.86     91.40       16.11
# 9     80.55     33.15       15.17
# 10   -94.76     89.60       11.41
# 11   -25.43     69.80        3.36
# 12   -68.31     39.20        4.70
# 13   -56.15     46.47        1.05
# 14   -73.98     75.99        5.82
# 15  -135.06     68.00        5.82
# 16    74.49     76.35        4.29
# 17   115.35     48.00       13.87
# 18    21.52     69.69        0.83
# 19  -124.16     68.00       12.75
# 20   -70.91     41.00       16.11
# 21    63.05     80.13        4.68
# 22   -37.64     44.60        9.17
# 23   -41.05     68.00        4.70
# 24    26.89     61.00        1.01
# 25   170.27     39.45        7.74
# 26   -73.75     79.00       17.22
# 27  -124.16     68.00       18.34
# 28   129.76     70.77        2.30
# 29   161.30     67.53        8.84
# ..      ...       ...         ...
# 518    9.93     75.20        4.70
# 519   33.22     45.75        3.56
# 520   80.98     76.17        3.96
# 521  145.91     44.01       17.00
# 522  -55.89     77.00        3.36
# 523  -90.18     91.40        3.36
# 524   94.90     73.83        1.83
# 525   -5.16     72.93        3.76
# 526   61.21     67.71        2.80
# 527   -7.36     73.29        5.70
# 528  -72.28     82.40       14.99
# 529   -2.24     74.37        9.62
# 530  126.91     76.89        4.99
# 531  -60.67     80.13        4.85
# 532   24.66     78.15        2.04
# 533 -158.01     89.60       17.22
# 534 -151.33     71.67       11.23
# 535   45.21     68.00       21.92
# 536   -2.07     75.99        7.00
# 537   -7.53     69.80        8.05
# 538  176.76     62.01        1.01
# 539   -6.54     77.00        3.94
# 540   72.64     82.65       10.63
# 541  122.30     74.73       12.06
# 542  -74.12     80.85        4.32
# 543  -80.61     60.80       10.29
# 544   46.32     78.80        2.24
# 545  -76.20     71.60        9.17
# 546  -97.45     83.55       10.11
# 547   39.00     68.00        9.17
#
# [548 rows x 9 columns]

# %%
weather_data_df.to_html('weather_data.html')
